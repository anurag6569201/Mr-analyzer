# %% [markdown]
# Importing dependies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing datasets

# %%
merged_dataset1=pd.read_csv('merged_dataset1.csv')
imdb_movies=pd.read_csv('imdb_movies.csv')

# %%
merged_dataset1.shape
# Out:
# (115358, 5)

# %%
imdb_movies.shape
# Out:
# (10178, 12)

# %%
merged_dataset1.head()
# Out:
#                           movie_name  runtime                      director  \
# 0     Black Panther: Wakanda Forever  161 min                  Ryan Coogler
# 1           Avatar: The Way of Water  192 min                 James Cameron
# 2                              Plane  107 min          Jean-François Richet
# 3  Everything Everywhere All at Once  139 min  Dan Kwan, \nDaniel Scheinert
# 4  Ant-Man and the Wasp: Quantumania  125 min                   Peyton Reed
#
#               star     votes
# 0   Letitia Wright  204835.0
# 1  Sam Worthington  295119.0
# 2    Gerard Butler   26220.0
# 3    Michelle Yeoh  327858.0
# 4        Paul Rudd    5396.0

# %%
imdb_movies.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %% [markdown]
# Merging the datatset on the basis of movies names

# %%
merged_final_dataset = imdb_movies.merge(merged_dataset1, left_on='names', right_on='movie_name', how='inner')

# %%
merged_final_dataset.drop('movie_name', axis=1, inplace=True)

# %%
merged_final_dataset.head()
# Out:
#                           names       date_x  score  \
# 0      Avatar: The Way of Water  12/15/2022    78.0
# 1                       Mummies  01/05/2023    70.0
# 2                     Supercell  03/17/2023    61.0
# 3  Puss in Boots: The Last Wish  12/26/2022    83.0
# 4               Attack on Titan  09/30/2022    59.0
#
#                                            genre  \
# 0             Science Fiction, Adventure, Action
# 1  Animation, Comedy, Family, Adventure, Fantasy
# 2                                         Action
# 3  Animation, Family, Fantasy, Adventure, Comedy
# 4                        Action, Science Fiction
#
#                                             overview  \
# 0  Set more than a decade after the events of the...
# 1  Through a series of unfortunate events, three ...
# 2  Good-hearted teenager William always lived in ...
# 3  Puss in Boots discovers that his passion for a...
# 4  As viable water is depleted on Earth, a missio...
#
#                                                 crew  \
# 0  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 1  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 2  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 3  Antonio Banderas, Puss in Boots (voice), Salma...
# 4  Paul Bianchi, Computer (voice), Erin Coker, Al...
#
#                      orig_title     status            orig_lang     budget_x  \
# 0      Avatar: The Way of Water   Released              English  460000000.0
# 1                        Momias   Released   Spanish, Castilian   12300000.0
# 2                     Supercell   Released              English   77000000.0
# 3  Puss in Boots: The Last Wish   Released              English   90000000.0
# 4               Attack on Titan   Released              English   71000000.0
#
#         revenue country  runtime                         director  \
# 0  2.316795e+09      AU  192 min                    James Cameron
# 1  3.420000e+07      AU   88 min        Juan Jesús García Galocha
# 2  3.409420e+08      US  149 min                    Jordan Wilson
# 3  4.834806e+08      AU  102 min  Joel Crawford, \nJanuel Mercado
# 4  2.549465e+08      US   91 min                        Noah Luke
#
#                star     votes
# 0   Sam Worthington  295119.0
# 1    Óscar Barberán     749.0
# 2     Jordan Wilson       6.0
# 3  Antonio Banderas   75016.0
# 4      Michael Paré      56.0

# %%
merged_final_dataset.shape
# Out:
# (7241, 16)

# %%
merged_final_dataset.to_csv('../dataset3/merged_dataset2.csv', index=False)
