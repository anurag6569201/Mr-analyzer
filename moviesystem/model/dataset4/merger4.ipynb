# %%
import numpy as np
import pandas as pd

# %%
dataframe_tmdb=pd.read_csv('TMDB_movie_dataset_v11.csv')

# %%
dataframe_tmdb.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
dataframe_tmdb.shape
# Out:
# (1052039, 24)

# %%
features_dataframe=dataframe_tmdb[['title','backdrop_path','poster_path','tagline']]

# %%
features_dataframe.head()
# Out:
#              title                     backdrop_path  \
# 0        Inception  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg
# 1     Interstellar  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg
# 2  The Dark Knight  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg
# 3           Avatar  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 4     The Avengers  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
#
#                         poster_path  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.

# %%
features_dataframe.isnull().sum()
# Out:
# title                12
# backdrop_path    762277
# poster_path      306672
# tagline          901872
# dtype: int64

# %%
features_dataframe.dropna(subset=['title'])
features_dataframe.dropna(subset=['poster_path'])
features_dataframe.dropna(subset=['tagline'])
# Out:
#                               title                     backdrop_path  \
# 0                         Inception  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg
# 1                      Interstellar  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg
# 2                   The Dark Knight  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg
# 3                            Avatar  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 4                      The Avengers  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# ...                             ...                               ...
# 1051997             Shotgun Freeway  /a6RsovA5WKR2YUVpXxf8OYTPvn5.jpg
# 1051998             Brother Complex  /4QWVhpy9EfiEf91PbrfYVlZiG7n.jpg
# 1052022                 I Stay Home  /5ms00JmjVEmN9E9wwlhVyqaxuro.jpg
# 1052024  Please Make Me Lesbian! 19  /5cnLbNS3e5AHtwEXVdNxX8dBkXu.jpg
# 1052030    Secrets of Titty F*cking                               NaN
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1051997  /6w45WtPFVLdexEMFwQzbsTha9WF.jpg
# 1051998  /tbLIN86YHT7rAbh1f72zMvxnvcM.jpg
# 1052022  /9bGCn7JP2mQcRHU2JCaMoUJCgQH.jpg
# 1052024  /zDbOK5qFeUMpN3GCq6GRcyOesmz.jpg
# 1052030  /bC8SmBxR58t6ydJmwq7IQ87zbaz.jpg
#
#                                                    tagline
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1051997                           Drives through Lost L.A.
# 1051998               That summer they fell into bad love-
# 1052022                              Diary of a quarantine
# 1052024     Girls Who Beg Pretty Please, With Sugar On Top
# 1052030                     A 4-Hr. Genuine Vivid Jugfest!
#
# [150167 rows x 4 columns]

# %%
merged_dataset3=pd.read_csv('merged_dataset3.csv')

# %%
merged_dataset3.shape
# Out:
# (5868, 18)

# %%
merged_dataset3.head()
# Out:
#                           names       date_x  score  \
# 0      Avatar: The Way of Water  12/15/2022    78.0
# 1                     Supercell  03/17/2023    61.0
# 2  Puss in Boots: The Last Wish  12/26/2022    83.0
# 3               Attack on Titan  09/30/2022    59.0
# 4                  The Exorcist  11/02/2022    55.0
#
#                                            genre  \
# 0             Science Fiction, Adventure, Action
# 1                                         Action
# 2  Animation, Family, Fantasy, Adventure, Comedy
# 3                        Action, Science Fiction
# 4                                         Horror
#
#                                             overview  \
# 0  Set more than a decade after the events of the...
# 1  Good-hearted teenager William always lived in ...
# 2  Puss in Boots discovers that his passion for a...
# 3  As viable water is depleted on Earth, a missio...
# 4  Ophelia, a young nun recently arriving in the ...
#
#                                                 crew  \
# 0  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 1  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 2  Antonio Banderas, Puss in Boots (voice), Salma...
# 3  Paul Bianchi, Computer (voice), Erin Coker, Al...
# 4  María Evoli, Ofelia, Diana Bracho, , Tina Rome...
#
#                      orig_title     status            orig_lang     budget_x  \
# 0      Avatar: The Way of Water   Released              English  460000000.0
# 1                     Supercell   Released              English   77000000.0
# 2  Puss in Boots: The Last Wish   Released              English   90000000.0
# 3               Attack on Titan   Released              English   71000000.0
# 4                  La Exorcista   Released   Spanish, Castilian   12000000.0
#
#         revenue country  runtime                         director  \
# 0  2.316795e+09      AU  192 min                    James Cameron
# 1  3.409420e+08      US  149 min                    Jordan Wilson
# 2  4.834806e+08      AU  102 min  Joel Crawford, \nJanuel Mercado
# 3  2.549465e+08      US   91 min                        Noah Luke
# 4  4.282145e+08      MX  122 min                 William Friedkin
#
#                star     votes UserRating  \
# 0   Sam Worthington  295119.0          0
# 1     Jordan Wilson       6.0          0
# 2  Antonio Banderas   75016.0          0
# 3      Michael Paré      56.0          0
# 4     Ellen Burstyn  414031.0       395K
#
#                                          PlotKyeword
# 0  ['sequel', 'second part', 'disney', 'science f...
# 1                                                 []
# 2  ['shared universe', 'sequel', 'second part', '...
# 3  ['live action remake of anime', 'survival', 'k...
# 4  ['exorcist', 'exorcism', 'demonic possession',...

# %%
merged_final_dataset_result = merged_dataset3.merge(features_dataframe, left_on='names', right_on='title', how='inner')

# %%
merged_final_dataset_result.duplicated(subset=['title']).sum()
# Out:
# 22177

# %%
merged_final_dataset_result.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %%
merged_final_dataset_result.shape
# Out:
# (5367, 22)

# %%
merged_final_dataset_result.drop(columns='title',axis=0)
# Out:
#                                              names       date_x  score  \
# 0                         Avatar: The Way of Water  12/15/2022    78.0
# 1                                        Supercell  03/17/2023    61.0
# 4                     Puss in Boots: The Last Wish  12/26/2022    83.0
# 5                                  Attack on Titan  09/30/2022    59.0
# 7                                     The Exorcist  11/02/2022    55.0
# ...                                            ...          ...    ...
# 27537  The Seven Deadly Sins: Prisoners of the Sky  08/18/2018    76.0
# 27538                            The Lady Vanishes  10/07/1938    75.0
# 27541      Delta Force 2: The Colombian Connection  08/24/1990    54.0
# 27542                             The Russia House  12/21/1990    61.0
# 27543           The Swan Princess: A Royal Wedding  07/20/2020    70.0
#
#                                                genre  \
# 0                 Science Fiction, Adventure, Action
# 1                                             Action
# 4      Animation, Family, Fantasy, Adventure, Comedy
# 5                            Action, Science Fiction
# 7                                             Horror
# ...                                              ...
# 27537          Action, Adventure, Fantasy, Animation
# 27538                      Mystery, Thriller, Comedy
# 27541                                         Action
# 27542                       Drama, Thriller, Romance
# 27543                     Animation, Family, Fantasy
#
#                                                 overview  \
# 0      Set more than a decade after the events of the...
# 1      Good-hearted teenager William always lived in ...
# 4      Puss in Boots discovers that his passion for a...
# 5      As viable water is depleted on Earth, a missio...
# 7      Ophelia, a young nun recently arriving in the ...
# ...                                                  ...
# 27537  Traveling in search of the rare ingredient, “s...
# 27538  On a train headed for England a group of trave...
# 27541  When DEA agents are taken captive by a ruthles...
# 27542  Barley Scott Blair, a Lisbon-based editor of R...
# 27543  Princess Odette and Prince Derek are going to ...
#
#                                                     crew  \
# 0      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 1      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 4      Antonio Banderas, Puss in Boots (voice), Salma...
# 5      Paul Bianchi, Computer (voice), Erin Coker, Al...
# 7      María Evoli, Ofelia, Diana Bracho, , Tina Rome...
# ...                                                  ...
# 27537  Yuki Kaji, Meliodas (voice), Sora Amamiya, Eli...
# 27538  Margaret Lockwood, Iris Matilda Henderson, Mic...
# 27541  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 27542  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 27543  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     orig_title     status  \
# 0                     Avatar: The Way of Water   Released
# 1                                    Supercell   Released
# 4                 Puss in Boots: The Last Wish   Released
# 5                              Attack on Titan   Released
# 7                                 La Exorcista   Released
# ...                                        ...        ...
# 27537                        劇場版 七つの大罪 天空の囚われ人   Released
# 27538                        The Lady Vanishes   Released
# 27541  Delta Force 2: The Colombian Connection   Released
# 27542                         The Russia House   Released
# 27543       The Swan Princess: A Royal Wedding   Released
#
#                  orig_lang     budget_x  ...  country  runtime  \
# 0                  English  460000000.0  ...       AU  192 min
# 1                  English   77000000.0  ...       US  149 min
# 4                  English   90000000.0  ...       AU  102 min
# 5                  English   71000000.0  ...       US   91 min
# 7       Spanish, Castilian   12000000.0  ...       MX  122 min
# ...                    ...          ...  ...      ...      ...
# 27537             Japanese   62600000.0  ...       JP   99 min
# 27538              English  132000000.0  ...       GB   95 min
# 27541              English    9145817.8  ...       US  111 min
# 27542              English   21800000.0  ...       US  123 min
# 27543              English   92400000.0  ...       GB   83 min
#
#                                director              star     votes  \
# 0                         James Cameron   Sam Worthington  295119.0
# 1                         Jordan Wilson     Jordan Wilson       6.0
# 4       Joel Crawford, \nJanuel Mercado  Antonio Banderas   75016.0
# 5                             Noah Luke      Michael Paré      56.0
# 7                      William Friedkin     Ellen Burstyn  414031.0
# ...                                 ...               ...       ...
# 27537  Yasuto Nishikata, \nNoriyuki Abe         Yûki Kaji    5025.0
# 27538                      Anthony Page     Elliott Gould    2836.0
# 27541                      Aaron Norris      Chuck Norris    7695.0
# 27542                     Fred Schepisi      Sean Connery   16624.0
# 27543                      Richard Rich       Nina Herzog     115.0
#
#        UserRating                                        PlotKyeword  \
# 0               0  ['sequel', 'second part', 'disney', 'science f...
# 1               0                                                 []
# 4               0  ['shared universe', 'sequel', 'second part', '...
# 5               0  ['live action remake of anime', 'survival', 'k...
# 7            395K  ['exorcist', 'exorcism', 'demonic possession',...
# ...           ...                                                ...
# 27537        4.8K               ['based on manga', 'based on anime']
# 27538        2.7K  ['disappearance', "questioning one's sanity", ...
# 27541        7.5K  ['martial arts', 'kung fu', 'cult film', 'resc...
# 27542         16K  ['kgb agent', 'east west', 'soviet citizen', '...
# 27543         104  ['love', 'swan lake', 'swan princess', 'based ...
#
#                           backdrop_path                       poster_path  \
# 0      /8rpDcsfLJypbO6vREc0547VKqEv.jpg  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg
# 1      /m1fgGSLK0WvRpzM1AmZu38m0Tx8.jpg  /gbGHezV6yrhua0KfAgwrknSOiIY.jpg
# 4      /b1Y8SUb12gPHCSSSNlbX4nB3IKy.jpg  /kuf6dutpsT0vSVehic3EZIqkOBt.jpg
# 5      /qRik98bxXPn4qCHTe3ffhbGFRAu.jpg  /ihuDg9TeRzoOhv2cZVA8gi50NFl.jpg
# 7      /huC0x1don81NMreSGx4ITkrv9aG.jpg  /4ucLGcXVVSVnsfkGtbLY4XAius8.jpg
# ...                                 ...                               ...
# 27537  /e6CnfsN7wnhZEMqh5EnCfTDXQ7g.jpg  /63NOOAkaZAK8h93Sg7Ucq6XLJGP.jpg
# 27538  /exVKV32K0wGNXRL5kpqSfGs4InV.jpg  /c1t9LB76LvEARPanfEzXmkm7fwY.jpg
# 27541  /7JeFewm9SU2ISqg4qzRBoaimLva.jpg  /39UjuuaH2Gms6E7c8QWF7BdYSn8.jpg
# 27542  /vPdb3zCAS4nxdRkc5S2hp1zh4pQ.jpg  /yKSW5346x1rBi2h9EbWAbyi4jks.jpg
# 27543  /12oPPNSAKabqcwCd8CJSYL0A6p5.jpg  /mJaNBADFKRiMys8DiGemrLGYd9U.jpg
#
#                                                  tagline
# 0                                     Return to Pandora.
# 1                                       The chase is on.
# 4               Live each adventure like it's your last.
# 5                     The face of humanity's extinction.
# 7      Something almost beyond comprehension is happe...
# ...                                                  ...
# 27537                                                NaN
# 27538  Spies! Playing the game of love - and sudden d...
# 27541                      Norris and the force are back
# 27542  Their love was as dangerous as the secrets the...
# 27543                                                NaN
#
# [5367 rows x 21 columns]

# %%
merged_final_dataset_result['movie_id'] = range(1, len(merged_final_dataset_result) + 1)

# %%
merged_final_dataset_result.to_csv('../dataset5/merged_dataset4.csv', index=False)
