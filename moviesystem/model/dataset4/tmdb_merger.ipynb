# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movie_df=pd.read_csv('TMDB_movie_dataset_v11.csv')

# %%
movie_df.isnull().sum()
# Out:
# id                           0
# title                       12
# vote_average                 0
# vote_count                   0
# status                       0
# release_date            140177
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           762277
# budget                       0
# homepage                938510
# imdb_id                 468068
# original_language            0
# original_title              12
# overview                196042
# popularity                   0
# poster_path             306672
# tagline                 901872
# genres                  400406
# production_companies    561380
# production_countries    442154
# spoken_languages        427842
# keywords                754826
# dtype: int64

# %%
movie_df.dropna(subset=['title'],inplace=True)
movie_df.dropna(subset=['poster_path'],inplace=True)
movie_df.dropna(subset=['tagline'],inplace=True)
movie_df.dropna(subset=['keywords'],inplace=True)
movie_df.dropna(subset=['imdb_id'],inplace=True)
movie_df.dropna(subset=['genres'],inplace=True)
movie_df.dropna(subset=['production_companies'],inplace=True)
movie_df.dropna(subset=['overview'],inplace=True)
movie_df.dropna(subset=['homepage'],inplace=True)

# %%
movie_df.shape
# Out:
# (12601, 24)

# %%
movie_df.isnull().sum()
# Out:
# id                         0
# title                      0
# vote_average               0
# vote_count                 0
# status                     0
# release_date             217
# revenue                    0
# runtime                    0
# adult                      0
# backdrop_path           2298
# budget                     0
# homepage                   0
# imdb_id                    0
# original_language          0
# original_title             0
# overview                   0
# popularity                 0
# poster_path                0
# tagline                    0
# genres                     0
# production_companies       0
# production_countries     800
# spoken_languages         671
# keywords                   0
# dtype: int64

# %%
movie_df[movie_df['vote_count'] != 5000]
# Out:
#              id                   title  vote_average  vote_count    status  \
# 0         27205               Inception         8.364       34495  Released
# 1        157336            Interstellar         8.417       32571  Released
# 2           155         The Dark Knight         8.512       30619  Released
# 3         19995                  Avatar         7.573       29815  Released
# 4         24428            The Avengers         7.710       29166  Released
# ...         ...                     ...           ...         ...       ...
# 1051374  691432  Nothing Like Chocolate         0.000           0  Released
# 1051506  691666            K9 Guardians         0.000           0  Released
# 1051670  691549        Deep Condolences         0.000           0  Released
# 1051973  690844          Something Blue         0.000           0  Released
# 1051981  690829           Evan's Gambit         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 0         2010-07-15   825532764      148  False
# 1         2014-11-05   701729206      169  False
# 2         2008-07-16  1004558444      152  False
# 3         2009-12-15  2923706026      162  False
# 4         2012-04-25  1518815515      143  False
# ...              ...         ...      ...    ...
# 1051374   2012-01-29           0       68  False
# 1051506   2015-06-15           0       86  False
# 1051670   2018-01-02           0       11  False
# 1051973   2020-12-15           0       22  False
# 1051981   2019-01-24           0      121  False
#
#                             backdrop_path  ...          original_title  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...               Inception
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...            Interstellar
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...         The Dark Knight
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...                  Avatar
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...            The Avengers
# ...                                   ...  ...                     ...
# 1051374                               NaN  ...  Nothing Like Chocolate
# 1051506                               NaN  ...            K9 Guardians
# 1051670  /jHc9MsZlfJvOstwJWxRq6qhmCuI.jpg  ...       Turut Berdukacita
# 1051973  /3GT98qYs2JxWMCMxEuZVTYjcqJw.jpg  ...          Something Blue
# 1051981  /xWmRAy95Djll3ClNMRgGQpznAmi.jpg  ...           Evan's Gambit
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1051374  Deep in the rain forests of Grenada, anarchist...      0.600
# 1051506  Paul Ludwig, a K9 police officer and handler h...      1.029
# 1051670  Maria recounted the chronology of her father's...      0.600
# 1051973  A lonely wedding photographer falls for a wedd...      0.600
# 1051981  Two brothers, raised by a chess master, must b...      1.139
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1051374  /ck3PmLbNFiEVKThumr5BIU8BTns.jpg
# 1051506  /wzeKry0dI7eiqJQlfl27iQJSFMY.jpg
# 1051670  /k6aizii1dztEAdqBhVvClwV2vXp.jpg
# 1051973  /2FRjlDaSAMTKuohlElM522cxwCs.jpg
# 1051981  /5CeJrDsC5X93zYnnhUW2YCDyYNu.jpg
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1051374              A different kind of chocolate factory
# 1051506                                        Police Dogs
# 1051670                                   Deep Condolences
# 1051973   Things were old, She was new, He was borrowed...
# 1051981              It's not a game if it drives you mad.
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1051374                                  Documentary
# 1051506                                  Documentary
# 1051670                                        Drama
# 1051973                       Romance, Drama, Comedy
# 1051981                                        Drama
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1051374                            Mirror and Hammer Films
# 1051506                                          IrondogK9
# 1051670                                  Hore Besok Libur!
# 1051973                         640 Films, HME Productions
# 1051981                                    HME Productions
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1051374         Grenada, United States of America
# 1051506                  United States of America
# 1051670                                 Indonesia
# 1051973                                       NaN
# 1051981                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1051374                             English
# 1051506                                 NaN
# 1051670                          Indonesian
# 1051973                                 NaN
# 1051981                                 NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1051374                       chocolaterie, woman director
# 1051506                            police, dog, police dog
# 1051670                 dying and death, funeral, grieving
# 1051973  photographer, wedding reception, interracial r...
# 1051981  chess, violent father, chess champion, family ...
#
# [12601 rows x 24 columns]

# %%
movie_df.shape
# Out:
# (12601, 24)

# %%
movie_df.duplicated(subset=['title']).sum()
# Out:
# 252

# %%
movie_df.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %%
movie_df.shape
movie_df['movie_id'] = range(1, len(movie_df) + 1)

# %%
movie_df.to_csv('../dataset5/TMDB_new_dataset.csv', index=False)
