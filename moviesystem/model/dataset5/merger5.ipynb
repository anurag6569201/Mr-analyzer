# %% [markdown]
# Importing dependies

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# loading the dataset and preview it

# %%
movie_df=pd.read_csv('merged_dataset4.csv')

# %%
movie_df.head()
# Out:
#                           names       date_x  score  \
# 0      Avatar: The Way of Water  12/15/2022    78.0
# 1                     Supercell  03/17/2023    61.0
# 2  Puss in Boots: The Last Wish  12/26/2022    83.0
# 3               Attack on Titan  09/30/2022    59.0
# 4                  The Exorcist  11/02/2022    55.0
#
#                                            genre  \
# 0             Science Fiction, Adventure, Action
# 1                                         Action
# 2  Animation, Family, Fantasy, Adventure, Comedy
# 3                        Action, Science Fiction
# 4                                         Horror
#
#                                             overview  \
# 0  Set more than a decade after the events of the...
# 1  Good-hearted teenager William always lived in ...
# 2  Puss in Boots discovers that his passion for a...
# 3  As viable water is depleted on Earth, a missio...
# 4  Ophelia, a young nun recently arriving in the ...
#
#                                                 crew  \
# 0  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 1  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 2  Antonio Banderas, Puss in Boots (voice), Salma...
# 3  Paul Bianchi, Computer (voice), Erin Coker, Al...
# 4  María Evoli, Ofelia, Diana Bracho, , Tina Rome...
#
#                      orig_title     status            orig_lang     budget_x  \
# 0      Avatar: The Way of Water   Released              English  460000000.0
# 1                     Supercell   Released              English   77000000.0
# 2  Puss in Boots: The Last Wish   Released              English   90000000.0
# 3               Attack on Titan   Released              English   71000000.0
# 4                  La Exorcista   Released   Spanish, Castilian   12000000.0
#
#    ...                         director              star     votes  \
# 0  ...                    James Cameron   Sam Worthington  295119.0
# 1  ...                    Jordan Wilson     Jordan Wilson       6.0
# 2  ...  Joel Crawford, \nJanuel Mercado  Antonio Banderas   75016.0
# 3  ...                        Noah Luke      Michael Paré      56.0
# 4  ...                 William Friedkin     Ellen Burstyn  414031.0
#
#   UserRating                                        PlotKyeword  \
# 0          0  ['sequel', 'second part', 'disney', 'science f...
# 1          0                                                 []
# 2          0  ['shared universe', 'sequel', 'second part', '...
# 3          0  ['live action remake of anime', 'survival', 'k...
# 4       395K  ['exorcist', 'exorcism', 'demonic possession',...
#
#                           title                     backdrop_path  \
# 0      Avatar: The Way of Water  /8rpDcsfLJypbO6vREc0547VKqEv.jpg
# 1                     Supercell  /m1fgGSLK0WvRpzM1AmZu38m0Tx8.jpg
# 2  Puss in Boots: The Last Wish  /b1Y8SUb12gPHCSSSNlbX4nB3IKy.jpg
# 3               Attack on Titan  /qRik98bxXPn4qCHTe3ffhbGFRAu.jpg
# 4                  The Exorcist  /huC0x1don81NMreSGx4ITkrv9aG.jpg
#
#                         poster_path  \
# 0  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg
# 1  /gbGHezV6yrhua0KfAgwrknSOiIY.jpg
# 2  /kuf6dutpsT0vSVehic3EZIqkOBt.jpg
# 3  /ihuDg9TeRzoOhv2cZVA8gi50NFl.jpg
# 4  /4ucLGcXVVSVnsfkGtbLY4XAius8.jpg
#
#                                              tagline movie_id
# 0                                 Return to Pandora.        1
# 1                                   The chase is on.        2
# 2           Live each adventure like it's your last.        3
# 3                 The face of humanity's extinction.        4
# 4  Something almost beyond comprehension is happe...        5
#
# [5 rows x 23 columns]

# %%
movie_df.shape
# Out:
# (5367, 23)

# %% [markdown]
# Selcting the relevent features

# %%
selected_features = ['genre', 'overview', 'crew', 'director', 'star', 'PlotKyeword', 'tagline']
print(selected_features)
# Out:
# ['genre', 'overview', 'crew', 'director', 'star', 'PlotKyeword', 'tagline']

# %%
# replacing the null valuess with null string

for feature in selected_features:
  movie_df[feature] = movie_df[feature].fillna('')

# %% [markdown]
# Combining the all relevant features

# %%
movie_df['combined_features'] = movie_df['genre'] + ' ' + movie_df['overview'] + ' ' + movie_df['crew'] + ' ' +movie_df['director'] + ' ' + movie_df['star'] + ' ' + movie_df['PlotKyeword'] + ' ' +movie_df['tagline']

# %% [markdown]
# Converting text data to feature vectors

# %%
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(movie_df['combined_features'])

# %%
print(feature_vectors)
# Out:
#   (0, 34141)	0.12985594424768382
#   (0, 38210)	0.08360947007921586
#   (0, 49286)	0.08484527465298719
#   (0, 35932)	0.07026094861769755
#   (0, 16574)	0.07987012806372572
#   (0, 25933)	0.08724629901712243
#   (0, 23737)	0.09501040171905183
#   (0, 16602)	0.08375920179853681
#   (0, 15504)	0.052036660818328445
#   (0, 12633)	0.09923352088961865
#   (0, 34348)	0.07261951237032074
#   (0, 40636)	0.08048128372920955
#   (0, 40912)	0.07154786570259099
#   (0, 7259)	0.08484527465298719
#   (0, 22951)	0.048546639756610374
#   (0, 2521)	0.14681831270944154
#   (0, 16765)	0.09234453442173017
#   (0, 17727)	0.07794028271838524
#   (0, 15433)	0.12985594424768382
#   (0, 13853)	0.11898484546404427
#   (0, 3014)	0.04912548578320196
#   (0, 30726)	0.11400969887478278
#   (0, 35914)	0.12985594424768382
#   (0, 7920)	0.12985594424768382
#   (0, 43051)	0.14184316612018003
#   :	:
#   (5366, 17462)	0.09565451231629113
#   (5366, 27456)	0.09098520302022431
#   (5366, 49325)	0.22132001502295282
#   (5366, 27348)	0.06743860832754746
#   (5366, 4070)	0.04487999215212819
#   (5366, 36765)	0.07044351536120262
#   (5366, 15018)	0.05416488496050484
#   (5366, 20430)	0.036585500328783646
#   (5366, 9548)	0.07214382984916633
#   (5366, 2525)	0.12436580002828927
#   (5366, 6933)	0.03797810182869053
#   (5366, 48759)	0.1403260192878017
#   (5366, 2076)	0.20845823194204746
#   (5366, 33407)	0.027325177307481872
#   (5366, 38384)	0.0492767247005008
#   (5366, 38821)	0.0847019778995916
#   (5366, 19906)	0.04116202356881233
#   (5366, 15504)	0.04490070323899219
#   (5366, 34348)	0.06266096100370099
#   (5366, 40912)	0.06173627275030251
#   (5366, 3014)	0.08477749432553754
#   (5366, 46162)	0.0178998327463903
#   (5366, 1947)	0.07843828320738268
#   (5366, 15468)	0.03761757920321226
#   (5366, 45682)	0.01633847172930353

# %% [markdown]
# Using cosine_similarity algo for finding similarity

# %%
similarity = cosine_similarity(feature_vectors)

# %%
similarity.shape
# Out:
# (5367, 5367)

# %% [markdown]
# Getting the name from user

# %%
movie_name=input().lower()

# %%
list_of_all_titles = movie_df['names'].str.lower().tolist()
print(list_of_all_titles)
# Out:
# ['avatar: the way of water', 'supercell', 'puss in boots: the last wish', 'attack on titan', 'the exorcist', 'black panther: wakanda forever', 'prizefighter: the life of jem belcher', 'knock at the cabin', 'consecration', 'black adam', 'm3gan', 'ant-man and the wasp: quantumania', 'john wick: chapter 2', 'black warrant', 'shotgun wedding', 'john wick: chapter 3 - parabellum', 'fall', 'lord of the streets', 'little dixie', 'bandit', 'troll', 'sonic the hedgehog 2', 'a bronx tale', 'top gun: maverick', 'the enforcer', 'avatar', 'thor: love and thunder', 'arctic void', 'terrifier 2', 'john wick', 'spider-man: no way home', 'dolphin boy', "guillermo del toro's pinocchio", 'nocebo', 'prey', 'hex', 'medieval', 'super mario bros.', 'transfusion', 'shazam!', 'all quiet on the western front', 'violent night', 'scream', 'devotion', 'the woman king', 'perfect addiction', 'doctor strange in the multiverse of madness', 'there are no saints', 'avengers: infinity war', 'smile', 'strange world', 'the ten commandments', 'minions: the rise of gru', 'creed ii', 'creed', 'beast', 'wrath of man', 'jeepers creepers: reborn', 'turning red', 'encanto', 'lyle, lyle, crocodile', 'hacksaw ridge', 'venus', 'the batman', 'life in a year', 'the chronicles of narnia: the lion, the witch and the wardrobe', 'the exorcism of god', 'ghosts of the ozarks', 'kompromat', 'air', 'disenchanted', 'luck', 'bullet train', 'night at the museum: kahmunrah rises again', 'sing 2', 'shark bait', 'shrek', 'everything everywhere all at once', 'the lair', 'evil eye', 'the price we pay', 'murder mystery', 'babylon', 'the lost city', 'cop secret', 'harry potter and the chamber of secrets', 'candy land', 'venom: let there be carnage', 'on the count of three', 'uncharted', 'dc league of super-pets', 'moonfall', 'unicorn wars', 'fantastic beasts: the secrets of dumbledore', 'cars 3', 'the ledge', 'interstellar', 'close', 'coraline', 'harry potter and the goblet of fire', 'piggy', 'orphan: first kill', 'polar', 'harry potter and the half-blood prince', 'noise', 'the infernal machine', 'abandoned', 'the avengers', 'exodus: gods and kings', 'wolf hound', 'the little mermaid', 'the wolf of wall street', 'brothers', 'harry potter and the prisoner of azkaban', 'out of the blue', 'broker', 'the black phone', 'avengers: endgame', 'harry potter and the order of the phoenix', 'the northman', 'after ever happy', 'on the line', 'ben-hur', 'hocus pocus 2', 'morbius', 'cars 2', 'tangled', 'fifty shades of grey', 'harry potter and the deathly hallows: part 2', 'monsters, inc.', 'the ice age adventures of buck wild', 'samaritan', 'godzilla vs. kong', 'paradise city', 'shang-chi and the legend of the ten rings', "zack snyder's justice league", 'lightyear', "pirates of the caribbean: at world's end", 'the school for good and evil', 'monstrous', 'shrek 2', 'the unbearable weight of massive talent', 'fifty shades freed', 'spider-man: into the spider-verse', 'harry potter and the deathly hallows: part 1', 'emily the criminal', 'blood', 'memory', 'whisper', 'the shack', 'eternals', 'dog', 'the invitation', 'the conjuring: the devil made me do it', 'control', 'mortal kombat', 'pirates of the caribbean: the curse of the black pearl', 'clifford the big red dog', 'cruella', 'the suicide squad', 'the bad guys', 'the remaining', 'the last: naruto the movie', 'pirates of the caribbean: on stranger tides', 'coco', 'the sea beast', 'toy story', 'the independent', 'joseph', 'titanic', 'the hunger games: mockingjay - part 1', 'the autopsy of jane doe', 'corrective measures', 'the jack in the box: awakening', 'choose or die', 'crawlspace', 'the good neighbor', 'son of god', 'resident evil: welcome to raccoon city', 'the pale blue eye', 'the lion king', 'avengers: age of ultron', 'me before you', 'luca', "pirates of the caribbean: dead man's chest", 'the menu', 'ice age', 'shrek forever after', 'ghostbusters: afterlife', 'sonic the hedgehog', 'secret headquarters', 'the princess and the frog', '365 days: this day',  ...

# %% [markdown]
# Printing the closed match with the inputed name using difflib

# %%
close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(close_match)
# Out:
# ['batman', 'fatman', 'ant-man']

# %%
close_match = close_match[0]
print(close_match)
# Out:
# batman

# %% [markdown]
# getting the index of the closest matched movie

# %%
for index, movie_title in enumerate(list_of_all_titles):
    if movie_title == movie_name:
        movie_index = movie_df.loc[index, 'movie_id']
        print(f"Index of '{movie_name}': {movie_index}")
        break
else:
    print(f"No match found for '{movie_name}'")
# Out:
# Index of 'batman': 1244

# %% [markdown]
# Getting similar movies names

# %%
similarity_score = list(enumerate(similarity[movie_index]))
print(similarity_score)
# Out:
# [(0, 0.019576138643834208), (1, 0.02193359780543883), (2, 0.013676598872655954), (3, 0.013492328229325863), (4, 0.020213417198495953), (5, 0.013157613271193185), (6, 0.01241264173068753), (7, 0.010082870803984349), (8, 0.011353836221719978), (9, 0.015176391401075373), (10, 0.015994454713579336), (11, 0.020554710061717187), (12, 0.01835289468522136), (13, 0.015316676377146884), (14, 0.031178360063061603), (15, 0.04665641953503528), (16, 0.017426367286416555), (17, 0.003666099241266563), (18, 0.024559734131534637), (19, 0.031778513064273185), (20, 0.006624697457249278), (21, 0.02249173623908822), (22, 0.02726146913265225), (23, 0.03241105330694263), (24, 0.011720280962506081), (25, 0.017260647337605812), (26, 0.022448656944446067), (27, 0.012337116517766526), (28, 0.012560697378528276), (29, 0.023744570346111327), (30, 0.031223392342257277), (31, 0.011527360929724416), (32, 0.005797957743828424), (33, 0.02313744868414963), (34, 0.04239668460320651), (35, 0.004615357334900369), (36, 0.01679684840168377), (37, 0.008733232637543095), (38, 0.010081734727034984), (39, 0.005121419432932837), (40, 0.024165645130660635), (41, 0.034558049938823665), (42, 0.011919174570701494), (43, 0.004270445519330431), (44, 0.01967023555622644), (45, 0.006507661330735597), (46, 0.019486282385099772), (47, 0.031366976998857495), (48, 0.026520865533048204), (49, 0.01380865635109487), (50, 0.010411041395692948), (51, 0.016871942569666426), (52, 0.01438812640466487), (53, 0.01220821255358758), (54, 0.017399938805090675), (55, 0.008357861998634471), (56, 0.03088447749767109), (57, 0.013027957802088352), (58, 0.017265151878710996), (59, 0.010988962928718551), (60, 0.056082810353831204), (61, 0.01320760281396093), (62, 0.01395946110559727), (63, 0.016083134497765147), (64, 0.013320324204675753), (65, 0.01111031370012113), (66, 0.009820948047514315), (67, 0.02824687145091601), (68, 0.01642111080725301), (69, 0.01095491359173787), (70, 0.012004900130266585), (71, 0.022595336747547306), (72, 0.012228632559048316), (73, 0.011407912982433637), (74, 0.01818926475374399), (75, 0.03275367445306567), (76, 0.005382481586653828), (77, 0.009481313557636466), (78, 0.021814387803753395), (79, 0.006080176461317845), (80, 0.033751542562189346), (81, 0.00815741000708398), (82, 0.017137117636063456), (83, 0.04017426934897972), (84, 0.008686592082402106), (85, 0.014319416560807763), (86, 0.040741320039955356), (87, 0.03479936333817054), (88, 0.012760102547753673), (89, 0.03228177546161907), (90, 0.015466919315899448), (91, 0.038420587500177183), (92, 0.013075286370509039), (93, 0.00978439170204518), (94, 0.0113312104059148), (95, 0.031743047067741746), (96, 0.01747114171877747), (97, 0.013367650080341086), (98, 0.021432635642083555), (99, 0.014416383550155624), (100, 0.006274566722700349), (101, 0.024279383234169668), (102, 0.014079422135306406), (103, 0.02920733932306328), (104, 0.012184628470646492), (105, 0.018219921619130764), (106, 0.010613571443138506), (107, 0.01809821092896532), (108, 0.012981254641061153), (109, 0.008724729190258412), (110, 0.03240108231465143), (111, 0.014513319983701782), (112, 0.031251133718525566), (113, 0.01792763540366142), (114, 0.023683944695846695), (115, 0.01637802567473629), (116, 0.029355091732549857), (117, 0.020942458108895386), (118, 0.009396089970509025), (119, 0.0205392486556208), (120, 0.015346686213727877), (121, 0.011869463491715854), (122, 0.025740091282826855), (123, 0.025208548059187246), (124, 0.003989677320073494), (125, 0.008713638061934242), (126, 0.019437609327860997), (127, 0.01991744410438571), (128, 0.010708453503643677), (129, 0.020577870437271873), (130, 0.004211444141379348), (131, 0.02122970869093252), (132, 0.025521359729645456), (133, 0.016378168549872788), (134, 0.003938282157783216), (135, 0.02402896183706748), (136, 0.011887222460217535), (137, 0.024344592742127108), (138, 0.015460082407292281), (139, 0.01904466040156361), (140, 0.022653627954681795), (141, 0.02022598764530603), (142, 0.021374770122332975), (143, ...

# %%
len(similarity_score)
# Out:
# 5367

# %% [markdown]
# Sorting similar movies

# %%
sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True) 
print(sorted_similar_movies)
# Out:
# [(1244, 1.0), (4352, 0.13762518189861883), (4531, 0.1292922207459289), (2566, 0.11527745345638139), (3589, 0.11029189702052182), (5159, 0.10362709965566327), (4166, 0.09909532139141855), (3893, 0.09902867989060572), (2357, 0.09597208021320734), (1645, 0.09464500076562195), (3801, 0.09156386857703676), (4773, 0.0915395362987685), (4217, 0.09141189463483483), (1850, 0.08739635122026332), (4694, 0.08643784127613914), (4835, 0.08588716518555946), (1999, 0.08311660369140195), (4667, 0.08250635610776633), (5179, 0.0811639493249511), (4510, 0.07935070019335884), (2848, 0.07917285224710019), (4048, 0.07881751559261606), (5291, 0.07873330443584527), (2278, 0.07836358701436281), (3525, 0.07834753340875647), (3802, 0.07776333221381425), (4148, 0.07721512964208156), (1236, 0.07681822899613118), (4240, 0.07605034124437583), (3977, 0.07592293934480558), (3304, 0.07589859522265585), (3544, 0.07524538674273605), (4072, 0.07500140769570454), (1391, 0.07438046717342288), (4283, 0.07391730248106863), (3597, 0.07367399480535647), (4123, 0.0732760473962779), (3132, 0.07302608086204952), (4292, 0.0726846175625833), (3787, 0.07234661658341955), (5013, 0.07076160766810558), (1377, 0.07043438624206559), (1974, 0.07001262955994736), (5048, 0.06927056264294207), (1851, 0.06881542637345824), (1455, 0.06829227751829045), (2597, 0.06773476515430932), (3305, 0.06759954372798242), (4656, 0.06755450170434378), (5111, 0.06723736031897044), (3840, 0.06720999225644674), (2621, 0.06698972427973711), (4674, 0.06698381647911864), (1626, 0.06601571269727768), (628, 0.0654904781651605), (2858, 0.06542924125780057), (1384, 0.06521186807199318), (3007, 0.06514424427123025), (1097, 0.06509141006617743), (1736, 0.06486688143486306), (1162, 0.06439231160642765), (1713, 0.06403786471818938), (3627, 0.06378885449027644), (867, 0.06352348972528543), (1858, 0.06337309714241038), (4615, 0.06316142477538715), (4239, 0.06315257570281738), (5336, 0.0629464231149218), (3976, 0.06279323705516394), (2909, 0.06272937001056171), (3692, 0.06265786990116158), (3212, 0.06256383510396502), (1059, 0.06231565671595829), (1871, 0.062285797517368076), (1179, 0.06193058560887904), (1720, 0.06189752075280919), (4019, 0.06164964324543364), (4051, 0.06096408703282212), (1210, 0.0603599277677239), (5121, 0.06031819644067607), (4271, 0.06031739373136798), (1358, 0.060299309352567186), (5196, 0.06019168882363774), (2314, 0.059998849510106575), (206, 0.05984907360364183), (1877, 0.059546517048497935), (2835, 0.05945532945441741), (4401, 0.05935954904765246), (3875, 0.059222588655226845), (2106, 0.059210794185491494), (1801, 0.05877358519875857), (3779, 0.05867178703244512), (3577, 0.05867035479325841), (432, 0.058508986151009905), (4594, 0.05772349784136343), (4968, 0.057640860250226446), (3396, 0.05716580861379886), (1053, 0.05707534802898786), (2780, 0.05697875070727893), (2675, 0.05693746031707826), (4151, 0.05684163515028509), (4597, 0.056257046955827526), (60, 0.056082810353831204), (826, 0.05595883934168412), (1747, 0.0558355164791456), (1753, 0.055729173284442074), (4313, 0.05514213905141802), (2407, 0.055090150464226974), (4312, 0.05475822691074206), (3362, 0.054637245223431524), (1145, 0.05463356361337075), (469, 0.05461836283542883), (4796, 0.0545741839571473), (3596, 0.05453392150908057), (4629, 0.05451289258490032), (966, 0.05449546307211137), (2290, 0.05431153093921728), (4930, 0.0541213903467888), (2455, 0.053970866804071614), (673, 0.05390048706284515), (3739, 0.053840635217709924), (1140, 0.05358957071916793), (1816, 0.05350219966528981), (3540, 0.05342680284757672), (3291, 0.053207739365266585), (3301, 0.052857723511901086), (2961, 0.05275883185680702), (3449, 0.052754829443851084), (5269, 0.05272957079368949), (2477, 0.052716091302286425), (3984, 0.05263968203540864), (3639, 0.052546699743249686), (3315, 0.05249573281700256), (1338, 0.05239179900428799), (3624, 0.052235562889184135), (4332, 0.05222656999748228), (2750, 0.05210307680387649), (4996, 0.05184046966262389), (2818, 0.0518 ...

# %% [markdown]
# Printing the suggested movies

# %%
print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movie_df[movie_df.movie_id==index]['names'].values[0]
  if (i<=30):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Batman
# 2 . Anonymous
# 3 . The Way Back
# 4 . Barbarella
# 5 . Dirty Sexy Saint
# 6 . The Killing Fields
# 7 . Come True
# 8 . Pi
# 9 . Ninja: Shadow of a Tear
# 10 . Us
# 11 . Shanghai Knights
# 12 . Restraint
# 13 . Bingo Hell
# 14 . Drive Angry
# 15 . The Fall
# 16 . Tales from the Crypt
# 17 . Hot Shots! Part Deux
# 18 . Cold Creek Manor
# 19 . Motel Hell
# 20 . Bad Country
# 21 . Fast & Furious
# 22 . Drillbit Taylor
# 23 . A Dark Truth
# 24 . The Marine
# 25 . The Wedding Date
# 26 . Raising Arizona
# 27 . Offender
# 28 . Batman: The Long Halloween, Part One
# 29 . Support Your Local Sheriff!
# 30 . Polaroid
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 7
#       5 for movie in sorted_similar_movies:
#       6   index = movie[0]
# ----> 7   title_from_index = movie_df[movie_df.movie_id==index]['names'].values[0]
#       8   if (i<=30):
#       9     print(i, '.',title_from_index)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
